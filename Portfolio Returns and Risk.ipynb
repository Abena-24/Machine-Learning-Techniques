# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
Prices = pd.read_csv('DATA.csv', index_col='Year')
Prices
# Out:
#             RPFMNCA   CENDIVR   RIGRSGA   HGMAA2G  VAR20GA   GAMBISA   \
# Year
# 01/05/2016     12.85    154.06     13.95     9.73     99.91   12.4309
# 01/06/2016     12.86    153.03     13.96     9.72    100.11   12.3199
# 01/07/2016     12.85    153.17     13.91     9.70     99.73   12.2842
# 01/08/2016     12.78    152.44     13.77     9.64     98.61   12.1767
# 01/11/2016     12.77    151.82     13.72     9.64     98.29   12.1142
# ...              ...       ...       ...      ...       ...       ...
# 11/02/2021     20.29    229.05     19.37    13.44    160.77   19.1280
# 11/03/2021     20.32    229.64     19.42    13.54    161.29   19.2639
# 11/04/2021     20.33    229.80     19.43    13.52    161.22   19.2753
# 11/05/2021     20.32    229.80     19.55    13.66    162.69   19.4368
# 12/05/2021     20.41    229.80     19.55    13.70    162.69   19.4368
#
#             SCHLIS1   TAMGLMA   TROITOI   SSGADDV  FCMSBGB
# Year
# ...

# %%
Ret= Prices.pct_change().apply(lambda x: np.log(1+x)) # CONVERT TO RETURN
Ret.head()
# Out:
#             RPFMNCA   CENDIVR   RIGRSGA    HGMAA2G  VAR20GA   GAMBISA   \
# Year
# 01/05/2016       NaN       NaN       NaN       NaN       NaN       NaN
# 01/06/2016  0.000778 -0.006708  0.000717 -0.001028  0.002000 -0.008969
# 01/07/2016 -0.000778  0.000914 -0.003588 -0.002060 -0.003803 -0.002902
# 01/08/2016 -0.005462 -0.004777 -0.010116 -0.006205 -0.011294 -0.008790
# 01/11/2016 -0.000783 -0.004075 -0.003638  0.000000 -0.003250 -0.005146
#
#             SCHLIS1   TAMGLMA   TROITOI    SSGADDV   FCMSBGB
# Year
# 01/05/2016       NaN       NaN       NaN       NaN       NaN
# 01/06/2016 -0.003261 -0.009498 -0.001787  0.002005 -0.003005
# 01/07/2016 -0.001886 -0.002179  0.003008 -0.002579  0.001671
# 01/08/2016 -0.010885  0.001174 -0.005554 -0.007680 -0.001145
# 01/11/2016 -0.001401 -0.011970  0.001698 -0.002315 -0.002859

# %%
Prices.plot(title='Stocks daily returns')
# Out:
# <AxesSubplot:title={'center':'Stocks daily returns'}, xlabel='Year'>

# %%
Ret.plot(title='Stocks daily returns')
# Out:
# <AxesSubplot:title={'center':'Stocks daily returns'}, xlabel='Year'>

# %%
Ann_Ret = Ret.mean()*252
print (Ann_Ret)
# Out:
# RPFMNCA     0.076506
# CENDIVR     0.066120
# RIGRSGA     0.055806
# HGMAA2G     0.056581
# VAR20GA     0.080623
# GAMBISA     0.073911
# SCHLIS1     0.055947
# TAMGLMA     0.084327
# TROITOI     0.064287
# SSGADDV     0.063526
# FCMSBGB     0.062201
# dtype: float64

# %%
Ann_Risk = Ret.std()*(252)**(0.5)
Ann_Risk
# Out:
# RPFMNCA     0.067662
# CENDIVR     0.056212
# RIGRSGA     0.054107
# HGMAA2G     0.047937
# VAR20GA     0.075710
# GAMBISA     0.071067
# SCHLIS1     0.055168
# TAMGLMA     0.078351
# TROITOI     0.058832
# SSGADDV     0.056288
# FCMSBGB     0.045101
# dtype: float64

# %%
Ret_Corr = Ret.corr()
Ret_Corr
# Out:
#           RPFMNCA   CENDIVR   RIGRSGA    HGMAA2G  VAR20GA   GAMBISA   \
# RPFMNCA   1.000000  0.603830  0.339640  0.553519  0.307264  0.590443
# CENDIVR   0.603830  1.000000  0.453906  0.713917  0.423463  0.722757
# RIGRSGA   0.339640  0.453906  1.000000  0.679607  0.872639  0.689775
# HGMAA2G   0.553519  0.713917  0.679607  1.000000  0.632414  0.796420
# VAR20GA   0.307264  0.423463  0.872639  0.632414  1.000000  0.632544
# GAMBISA   0.590443  0.722757  0.689775  0.796420  0.632544  1.000000
# SCHLIS1   0.632788  0.733586  0.517711  0.719441  0.384312  0.764280
# TAMGLMA   0.302239  0.406566  0.339486  0.397850  0.255481  0.428692
# TROITOI   0.588426  0.663249  0.330869  0.571839  0.371838  0.614859
# SSGADDV   0.367380  0.520979  0.765056  0.642315  0.775966  0.637935
# FCMSBGB   0.521257  0.525797  0.553782  0.597500  0.423710  0.690331
#
#           SCHLIS1   TAMGLMA   TROITOI    SSGADDV   FCMSBGB
# RPFMNCA   0.632788  0.302239  0.588426  0.367380  0.521257
# ...

# %%
covar = Ret.cov()
covar
# Out:
#           RPFMNCA   CENDIVR   RIGRSGA    HGMAA2G  VAR20GA   GAMBISA   \
# RPFMNCA   0.000018  0.000009  0.000005  0.000007  0.000006  0.000011
# CENDIVR   0.000009  0.000013  0.000005  0.000008  0.000007  0.000011
# RIGRSGA   0.000005  0.000005  0.000012  0.000007  0.000014  0.000011
# HGMAA2G   0.000007  0.000008  0.000007  0.000009  0.000009  0.000011
# VAR20GA   0.000006  0.000007  0.000014  0.000009  0.000023  0.000014
# GAMBISA   0.000011  0.000011  0.000011  0.000011  0.000014  0.000020
# SCHLIS1   0.000009  0.000009  0.000006  0.000008  0.000006  0.000012
# TAMGLMA   0.000006  0.000007  0.000006  0.000006  0.000006  0.000009
# TROITOI   0.000009  0.000009  0.000004  0.000006  0.000007  0.000010
# SSGADDV   0.000006  0.000007  0.000009  0.000007  0.000013  0.000010
# FCMSBGB   0.000006  0.000005  0.000005  0.000005  0.000006  0.000009
#
#           SCHLIS1   TAMGLMA   TROITOI    SSGADDV   FCMSBGB
# RPFMNCA   0.000009  0.000006  0.000009  0.000006  0.000006
# ...

# %%
# Randomly weighted portfolio's variance
w = {'RPFMNCA':0.09090,'CENDIVR':0.09090,'RIGRSGA':0.09090,'HGMAA2G':0.09090,'VAR20GA':0.09090,'GAMBISA':0.09090,'SCHLIS1':0.09090,'TAMGLMA':0.09090,'TROITOI':0.09090,'SSGADDV':0.09090,'FCMSBGB':0.09090}
port_var = covar.mul(w, axis=0).mul(w, axis=1).sum().sum()
Ann_port_std = (port_var*252)**(0.5)
print (port_var)
print (port_var*252)
# Out:
# 5.224474302371061e-07
# 0.00013165675241975073

# %%
Ann_port_std
# Out:
# 0.011474177635880958

# %%
Ann = Ret.mean()*252
Ann
# Out:
# RPFMNCA     0.076506
# CENDIVR     0.066120
# RIGRSGA     0.055806
# HGMAA2G     0.056581
# VAR20GA     0.080623
# GAMBISA     0.073911
# SCHLIS1     0.055947
# TAMGLMA     0.084327
# TROITOI     0.064287
# SSGADDV     0.063526
# FCMSBGB     0.062201
# dtype: float64

# %%
w = [0.09090,0.09090,0.09090,0.09090,0.09090,0.09090,0.09090,0.09090,0.09090,0.09090,0.09090]
port_er = (w*Ann).sum()
port_er
# Out:
# 0.06725110833373323

# %%
df = pd.read_csv('DATA.csv', index_col='Year')
df
# Out:
#             RPFMNCA   CENDIVR   RIGRSGA   HGMAA2G  VAR20GA   GAMBISA   \
# Year
# 01/05/2016     12.85    154.06     13.95     9.73     99.91   12.4309
# 01/06/2016     12.86    153.03     13.96     9.72    100.11   12.3199
# 01/07/2016     12.85    153.17     13.91     9.70     99.73   12.2842
# 01/08/2016     12.78    152.44     13.77     9.64     98.61   12.1767
# 01/11/2016     12.77    151.82     13.72     9.64     98.29   12.1142
# ...              ...       ...       ...      ...       ...       ...
# 11/02/2021     20.29    229.05     19.37    13.44    160.77   19.1280
# 11/03/2021     20.32    229.64     19.42    13.54    161.29   19.2639
# 11/04/2021     20.33    229.80     19.43    13.52    161.22   19.2753
# 11/05/2021     20.32    229.80     19.55    13.66    162.69   19.4368
# 12/05/2021     20.41    229.80     19.55    13.70    162.69   19.4368
#
#             SCHLIS1   TAMGLMA   TROITOI   SSGADDV  FCMSBGB
# Year
# ...

# %%
dind_er= df.pct_change().apply(lambda x: np.log(1+x)) # CONVERT TO RETURN
dind_er.head()
# Out:
#             RPFMNCA   CENDIVR   RIGRSGA    HGMAA2G  VAR20GA   GAMBISA   \
# Year
# 01/05/2016       NaN       NaN       NaN       NaN       NaN       NaN
# 01/06/2016  0.000778 -0.006708  0.000717 -0.001028  0.002000 -0.008969
# 01/07/2016 -0.000778  0.000914 -0.003588 -0.002060 -0.003803 -0.002902
# 01/08/2016 -0.005462 -0.004777 -0.010116 -0.006205 -0.011294 -0.008790
# 01/11/2016 -0.000783 -0.004075 -0.003638  0.000000 -0.003250 -0.005146
#
#             SCHLIS1   TAMGLMA   TROITOI    SSGADDV   FCMSBGB
# Year
# 01/05/2016       NaN       NaN       NaN       NaN       NaN
# 01/06/2016 -0.003261 -0.009498 -0.001787  0.002005 -0.003005
# 01/07/2016 -0.001886 -0.002179  0.003008 -0.002579  0.001671
# 01/08/2016 -0.010885  0.001174 -0.005554 -0.007680 -0.001145
# 01/11/2016 -0.001401 -0.011970  0.001698 -0.002315 -0.002859

# %%
ind_er = dind_er.mean()*252
ind_er
# Out:
# RPFMNCA     0.076506
# CENDIVR     0.066120
# RIGRSGA     0.055806
# HGMAA2G     0.056581
# VAR20GA     0.080623
# GAMBISA     0.073911
# SCHLIS1     0.055947
# TAMGLMA     0.084327
# TROITOI     0.064287
# SSGADDV     0.063526
# FCMSBGB     0.062201
# dtype: float64

# %%
corr_matrix = df.pct_change().apply(lambda x: np.log(1+x)).corr()
corr_matrix
# Out:
#           RPFMNCA   CENDIVR   RIGRSGA    HGMAA2G  VAR20GA   GAMBISA   \
# RPFMNCA   1.000000  0.603830  0.339640  0.553519  0.307264  0.590443
# CENDIVR   0.603830  1.000000  0.453906  0.713917  0.423463  0.722757
# RIGRSGA   0.339640  0.453906  1.000000  0.679607  0.872639  0.689775
# HGMAA2G   0.553519  0.713917  0.679607  1.000000  0.632414  0.796420
# VAR20GA   0.307264  0.423463  0.872639  0.632414  1.000000  0.632544
# GAMBISA   0.590443  0.722757  0.689775  0.796420  0.632544  1.000000
# SCHLIS1   0.632788  0.733586  0.517711  0.719441  0.384312  0.764280
# TAMGLMA   0.302239  0.406566  0.339486  0.397850  0.255481  0.428692
# TROITOI   0.588426  0.663249  0.330869  0.571839  0.371838  0.614859
# SSGADDV   0.367380  0.520979  0.765056  0.642315  0.775966  0.637935
# FCMSBGB   0.521257  0.525797  0.553782  0.597500  0.423710  0.690331
#
#           SCHLIS1   TAMGLMA   TROITOI    SSGADDV   FCMSBGB
# RPFMNCA   0.632788  0.302239  0.588426  0.367380  0.521257
# ...

# %%
cov_matrix = df.pct_change().apply(lambda x: np.log(1+x)).cov()
cov_matrix
# Out:
#           RPFMNCA   CENDIVR   RIGRSGA    HGMAA2G  VAR20GA   GAMBISA   \
# RPFMNCA   0.000018  0.000009  0.000005  0.000007  0.000006  0.000011
# CENDIVR   0.000009  0.000013  0.000005  0.000008  0.000007  0.000011
# RIGRSGA   0.000005  0.000005  0.000012  0.000007  0.000014  0.000011
# HGMAA2G   0.000007  0.000008  0.000007  0.000009  0.000009  0.000011
# VAR20GA   0.000006  0.000007  0.000014  0.000009  0.000023  0.000014
# GAMBISA   0.000011  0.000011  0.000011  0.000011  0.000014  0.000020
# SCHLIS1   0.000009  0.000009  0.000006  0.000008  0.000006  0.000012
# TAMGLMA   0.000006  0.000007  0.000006  0.000006  0.000006  0.000009
# TROITOI   0.000009  0.000009  0.000004  0.000006  0.000007  0.000010
# SSGADDV   0.000006  0.000007  0.000009  0.000007  0.000013  0.000010
# FCMSBGB   0.000006  0.000005  0.000005  0.000005  0.000006  0.000009
#
#           SCHLIS1   TAMGLMA   TROITOI    SSGADDV   FCMSBGB
# RPFMNCA   0.000009  0.000006  0.000009  0.000006  0.000006
# ...

# %%
w = [0.09090,0.09090,0.09090,0.09090,0.09090,0.09090,0.09090,0.09090,0.09090,0.09090,0.09090]
port_er = (w*Ann).sum()
port_er
# Out:
# 0.06725110833373323

# %%
# Volatility is given by the annual standard deviation. We multiply by 252 because there are 252 trading days/year.
ann_sd = df.pct_change().apply(lambda x: np.log(1+x)).std().apply(lambda x: x*np.sqrt(252))
ann_sd
# Out:
# RPFMNCA     0.067662
# CENDIVR     0.056212
# RIGRSGA     0.054107
# HGMAA2G     0.047937
# VAR20GA     0.075710
# GAMBISA     0.071067
# SCHLIS1     0.055168
# TAMGLMA     0.078351
# TROITOI     0.058832
# SSGADDV     0.056288
# FCMSBGB     0.045101
# dtype: float64

# %%
assets = pd.concat([ind_er, ann_sd], axis=1) # Creating a table for visualising returns and volatility of assets
assets.columns = ['Returns', 'Volatility']
assets
# Out:
#            Returns  Volatility
# RPFMNCA   0.076506    0.067662
# CENDIVR   0.066120    0.056212
# RIGRSGA   0.055806    0.054107
# HGMAA2G   0.056581    0.047937
# VAR20GA   0.080623    0.075710
# GAMBISA   0.073911    0.071067
# SCHLIS1   0.055947    0.055168
# TAMGLMA   0.084327    0.078351
# TROITOI   0.064287    0.058832
# SSGADDV   0.063526    0.056288
# FCMSBGB   0.062201    0.045101

# %%
import matplotlib.pyplot as plt
x = ann_sd # RISK
y = ind_er # Return
plt.scatter(x, y)
plt.show()

# %%
p_ret = [] # Define an empty array for portfolio returns
p_vol = [] # Define an empty array for portfolio volatility
p_weights = [] # Define an empty array for asset weights
num_assets = len(df.columns)
num_portfolios = 10000

# %%
for portfolio in range(num_portfolios):
    weights = np.random.random(num_assets)
    weights = weights/np.sum(weights)
    p_weights.append(weights)
    returns = np.dot(weights, ind_er) # Returns are the product of individual expected returns of asset and its
 # weights
    p_ret.append(returns)
    var = cov_matrix.mul(weights, axis=0).mul(weights, axis=1).sum().sum() # Portfolio Variance
    sd = np.sqrt(var) #Daily standard deviation
    ann_sd = sd*np.sqrt(252) #Annual standard deviation = volatility
    p_vol.append(ann_sd)

# %%
data = {'Returns':p_ret, 'Volatility':p_vol}
for counter, symbol in enumerate(df.columns.tolist()):
 #print(counter, symbol)
 data[symbol+'weight'] = [w[counter] for w in p_weights]
portfolios = pd.DataFrame(data)
portfolios.head() # Dataframe of the 10000 portfolios created
# Out:
#     Returns  Volatility  RPFMNCA weight  CENDIVR weight  RIGRSGA weight  \
# 0  0.067514    0.047481        0.070975        0.066681        0.132845
# 1  0.067639    0.044250        0.201877        0.002645        0.052868
# 2  0.069021    0.045122        0.104047        0.003254        0.067489
# 3  0.067899    0.045671        0.116462        0.158752        0.066261
# 4  0.069053    0.047183        0.135404        0.121660        0.123086
#
#    HGMAA2Gweight  VAR20GA weight  GAMBISA weight  SCHLIS1 weight  \
# 0       0.151712        0.182853        0.089503        0.030287
# 1       0.102753        0.062626        0.045610        0.024496
# 2       0.095573        0.080818        0.055210        0.080780
# 3       0.068625        0.127039        0.057128        0.009566
# 4       0.116224        0.114056        0.091302        0.067470
#
#    TAMGLMA weight  TROITOI weight  SSGADDVweight  FCMSBGBweight
# 0        0.058578        0.044142       0.092658       0.079767
# ...

# %%
# Plot efficient frontier
portfolios.plot.scatter(x='Volatility', y='Returns', marker='o', s=10, alpha=0.3, grid=True, figsize=[5,5])
# Out:
# <AxesSubplot:xlabel='Volatility', ylabel='Returns'>

# %%
min_vol_port = portfolios.iloc[portfolios['Volatility'].idxmin()]
# idxmin() gives us the minimum value in the column specified.
min_vol_port
# Out:
# Returns           0.064173
# Volatility        0.041809
# RPFMNCA weight    0.024963
# CENDIVR weight    0.041477
# RIGRSGA weight    0.220247
# HGMAA2Gweight     0.086518
# VAR20GA weight    0.001452
# GAMBISA weight    0.027218
# SCHLIS1 weight    0.009677
# TAMGLMA weight    0.117129
# TROITOI weight    0.154661
# SSGADDVweight     0.111185
# FCMSBGBweight     0.205474
# Name: 2676, dtype: float64

# %%
# plotting the minimum volatility portfolio
plt.subplots(figsize=[6,5])
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=200)

# %%
# Finding the optimal portfolio
rf = 0.01 # risk factor
optimal_risky_port = portfolios.iloc[((portfolios['Returns']-rf)/portfolios['Volatility']).idxmax()]
optimal_risky_port
# Out:
# Returns           0.072370
# Volatility        0.045157
# RPFMNCA weight    0.137091
# CENDIVR weight    0.129842
# RIGRSGA weight    0.006764
# HGMAA2Gweight     0.006020
# VAR20GA weight    0.125333
# GAMBISA weight    0.022029
# SCHLIS1 weight    0.025989
# TAMGLMA weight    0.241291
# TROITOI weight    0.000692
# SSGADDVweight     0.024178
# FCMSBGBweight     0.280769
# Name: 7719, dtype: float64

# %%
# Plotting optimal portfolio
plt.subplots(figsize=(5, 6))
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)
plt.scatter(optimal_risky_port[1], optimal_risky_port[0], color='g', marker='*', s=500)

# %%
#Sharpe ratio for optimal portfolio using a rf=0.01

Returns = 0.071743
Volatility = 0.043670
Risk_premium = 0.061743   #Risk premium = Expected return - Risk-free rate
Sharpe = print(Risk_premium/Volatility)
# Out:
# 1.4138539042821159
